# %% [markdown]
# <a href="https://colab.research.google.com/github/JuliaPerin/Arco-ris/blob/main/C%C3%B3digo_Arco_%C3%ADris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
<!DOCTYPE html>
<html lang="pt-BR">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>Clínica Espaço Arco-Íris | Desenvolvimento Infantil Especializado</title>
    <meta name="description" content="Clínica multidisciplinar especializada em desenvolvimento infantil com Psicologia, Fonoaudiologia, Psicopedagogia, Terapia Ocupacional e mais. Agende uma avaliação gratuita!">
    <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/font-awesome/6.4.0/css/all.min.css">
    <link rel="preconnect" href="https://fonts.googleapis.com">
    <link rel="preconnect" href="https://fonts.gstatic.com" crossorigin>
    <link href="https://fonts.googleapis.com/css2?family=Nunito:wght@400;600;700;800&family=Poppins:wght@400;500;600;700&display=swap" rel="stylesheet">
    <style>
        :root {
            --color-red: #ff5757;
            --color-orange: #ff9f57;
            --color-yellow: #ffde59;
            --color-green: #48d1a8;
            --color-blue: #5271ff;
            --color-purple: #b57aff;
            --color-dark: #333333;
            --color-text: #4a4a4a;
            --color-light: #f9f9f9;
            --color-primary: #ff5757;
            --color-secondary: #48d1a8;
            --color-accent: #5271ff;
            --shadow: 0 4px 12px rgba(0, 0, 0, 0.1);
            --radius: 12px;
            --transition: all 0.3s ease;
        }

        * {
            margin: 0;
            padding: 0;
            box-sizing: border-box;
        }

        body {
            font-family: 'Nunito', sans-serif;
            color: var(--color-text);
            line-height: 1.6;
            background-color: var(--color-light);
            overflow-x: hidden;
        }

        h1, h2, h3, h4, h5, h6 {
            font-family: 'Poppins', sans-serif;
            font-weight: 700;
            color: var(--color-dark);
            margin-bottom: 1rem;
        }

        h1 {
            font-size: clamp(2rem, 5vw, 3.5rem);
            line-height: 1.2;
            margin-bottom: 1.5rem;
        }

        h2 {
            font-size: clamp(1.5rem, 4vw, 2.5rem);
            margin-bottom: 1.2rem;
        }

        h3 {
            font-size: clamp(1.2rem, 3vw, 1.8rem);
            margin-bottom: 1rem;
        }

        p {
            margin-bottom: 1.5rem;
            font-size: 1.1rem;
        }

        img {
            max-width: 100%;
            height: auto;
        }

        a {
            color: var(--color-accent);
            text-decoration: none;
            transition: var(--transition);
        }

        a:hover {
            color: var(--color-primary);
        }

        .container {
            width: 100%;
            max-width: 1200px;
            margin: 0 auto;
            padding: 0 20px;
        }

        .btn {
            display: inline-block;
            background-color: var(--color-primary);
            color: white;
            font-weight: 700;
            font-size: 1.1rem;
            padding: 15px 30px;
            border-radius: var(--radius);
            border: none;
            cursor: pointer;
            transition: var(--transition);
            text-align: center;
            box-shadow: var(--shadow);
        }

        .btn:hover {
            background-color: #e04545;
            transform: translateY(-3px);
            box-shadow: 0 6px 15px rgba(255, 87, 87, 0.3);
            color: white;
        }

        .btn-secondary {
            background-color: var(--color-secondary);
        }

        .btn-secondary:hover {
            background-color: #3bb996;
            box-shadow: 0 6px 15px rgba(72, 209, 168, 0.3);
        }

        .btn-large {
            padding: 18px 36px;
            font-size: 1.2rem;
        }

        /* Header */
        header {
            background-color: white;
            box-shadow: var(--shadow);
            padding: 15px 0;
            position: sticky;
            top: 0;
            z-index: 100;
        }

        .header-container {
            display: flex;
            justify-content: space-between;
            align-items: center;
        }

        .logo {
            max-width: 220px;
        }

        .header-cta {
            display: flex;
            align-items: center;
            gap: 15px;
        }

        .header-phone {
            display: flex;
            align-items: center;
            gap: 8px;
            font-weight: 700;
            color: var(--color-dark);
        }

        .header-phone i {
            color: var(--color-primary);
        }

        /* Hero Section */
        .hero {
            padding: 80px 0;
            background: linear-gradient(135deg, rgba(255,255,255,0.9) 0%, rgba(255,255,255,0.7) 100%),
                        url('https://images.unsplash.com/photo-1602083973185-1fc5a2b0a4b4?ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8fA%3D%3D&auto=format&fit=crop&w=1287&q=80');
            background-size: cover;
            background-position: center;
            position: relative;
            overflow: hidden;
        }

        .hero::before {
            content: '';
            position: absolute;
            top: 0;
            left: 0;
            width: 100%;
            height: 100%;
            background: linear-gradient(135deg,
                rgba(255, 87, 87, 0.1) 0%,
                rgba(255, 159, 87, 0.1) 20%,
                rgba(255, 222, 89, 0.1) 40%,
                rgba(72, 209, 168, 0.1) 60%,
                rgba(82, 113, 255, 0.1) 80%,
                rgba(181, 122, 255, 0.1) 100%);
            z-index: -1;
        }

        .hero-content {
            max-width: 700px;
        }

        .hero-subtitle {
            font-size: clamp(1.1rem, 3vw, 1.5rem);
            color: var(--color-text);
            margin-bottom: 2rem;
        }

        .hero-cta {
            margin-top: 2.5rem;
        }

        /* Why Choose Us Section */
        .why-choose {
            padding: 80px 0;
            background-color: white;
        }

        .section-title {
            text-align: center;
            margin-bottom: 3rem;
        }

        .section-title h2 {
            position: relative;
            display: inline-block;
            padding-bottom: 15px;
        }

        .section-title h2::after {
            content: '';
            position: absolute;
            bottom: 0;
            left: 50%;
            transform: translateX(-50%);
            width: 80px;
            height: 4px;
            background: linear-gradient(to right, var(--color-red), var(--color-orange), var(--color-yellow), var(--color-green), var(--color-blue), var(--color-purple));
            border-radius: 2px;
        }

        .benefits-list {
            margin-top: 2rem;
        }

        .benefit-item {
            display: flex;
            align-items: flex-start;
            margin-bottom: 1.5rem;
        }

        .benefit-icon {
            flex-shrink: 0;
            width: 30px;
            height: 30px;
            background-color: var(--color-green);
            border-radius: 50%;
            display: flex;
            align-items: center;
            justify-content: center;
            margin-right: 15px;
            color: white;
        }

        .benefit-text {
            font-size: 1.1rem;
        }

        .connection-text {
            margin-top: 2rem;
            padding: 30px;
            background-color: var(--color-light);
            border-radius: var(--radius);
            box-shadow: var(--shadow);
        }

        .quote {
            font-style: italic;
            font-weight: 600;
            color: var(--color-accent);
            font-size: 1.2rem;
            margin: 2rem 0;
            padding-left: 20px;
            border-left: 4px solid var(--color-accent);
        }

        /* Services Section */
        .services {
            padding: 80px 0;
            background-color: var(--color-light);
        }

        .services-grid {
            display: grid;
            grid-template-columns: repeat(auto-fill, minmax(300px, 1fr));
            gap: 30px;
            margin-top: 3rem;
        }

        .service-card {
            background-color: white;
            border-radius: var(--radius);
            overflow: hidden;
            box-shadow: var(--shadow);
            transition: var(--transition);
        }

        .service-card:hover {
            transform: translateY(-5px);
            box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1);
        }

        .service-icon {
            height: 120px;
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 3rem;
            background: linear-gradient(135deg, var(--color-red), var(--color-orange));
            color: white;
        }

        .service-card:nth-child(2n) .service-icon {
            background: linear-gradient(135deg, var(--color-orange), var(--color-yellow));
        }

        .service-card:nth-child(3n) .service-icon {
            background: linear-gradient(135deg, var(--color-yellow), var(--color-green));
        }

        .service-card:nth-child(4n) .service-icon {
            background: linear-gradient(135deg, var(--color-green), var(--color-blue));
        }

        .service-card:nth-child(5n) .service-icon {
            background: linear-gradient(135deg, var(--color-blue), var(--color-purple));
        }

        .service-card:nth-child(6n) .service-icon {
            background: linear-gradient(135deg, var(--color-purple), var(--color-red));
        }

        .service-content {
            padding: 25px;
        }

        .service-title {
            font-size: 1.3rem;
            margin-bottom: 10px;
        }

        .service-description {
            font-size: 1rem;
            color: var(--color-text);
        }

        /* Attendance Section */
        .attendance {
            padding: 80px 0;
            background-color: white;
        }

        .attendance-options {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(300px, 1fr));
            gap: 30px;
            margin-top: 3rem;
        }

        .attendance-card {
            background-color: var(--color-light);
            border-radius: var(--radius);
            padding: 30px;
            box-shadow: var(--shadow);
        }

        .attendance-title {
            font-size: 1.5rem;
            margin-bottom: 15px;
            color: var(--color-primary);
        }

        .attendance-list {
            list-style: none;
            margin-bottom: 25px;
        }

        .attendance-list li {
            margin-bottom: 10px;
            display: flex;
            align-items: flex-start;
        }

        .attendance-list li i {
            color: var(--color-green);
            margin-right: 10px;
            margin-top: 5px;
        }

        .attendance-cta {
            margin-top: 20px;
            font-weight: 700;
            display: inline-block;
        }

        .attendance-cta i {
            margin-right: 8px;
        }

        /* CTA Section */
        .cta-section {
            padding: 80px 0;
            background: linear-gradient(135deg, var(--color-red), var(--color-orange), var(--color-yellow), var(--color-green), var(--color-blue), var(--color-purple));
            color: white;
            text-align: center;
        }

        .cta-section h2 {
            color: white;
            margin-bottom: 1.5rem;
        }

        .cta-text {
            max-width: 800px;
            margin: 0 auto 2.5rem;
            font-size: 1.2rem;
        }

        /* Form Section */
        .form-section {
            padding: 80px 0;
            background-color: var(--color-light);
        }

        .form-container {
            background-color: white;
            border-radius: var(--radius);
            box-shadow: var(--shadow);
            padding: 40px;
            max-width: 700px;
            margin: 0 auto;
        }

        .form-title {
            text-align: center;
            margin-bottom: 2rem;
        }

        .form-group {
            margin-bottom: 20px;
        }

        .form-label {
            display: block;
            margin-bottom: 8px;
            font-weight: 600;
        }

        .form-control {
            width: 100%;
            padding: 12px 15px;
            border: 1px solid #ddd;
            border-radius: var(--radius);
            font-family: 'Nunito', sans-serif;
            font-size: 1rem;
            transition: var(--transition);
        }

        .form-control:focus {
            outline: none;
            border-color: var(--color-accent);
            box-shadow: 0 0 0 3px rgba(82, 113, 255, 0.2);
        }

        textarea.form-control {
            min-height: 120px;
            resize: vertical;
        }

        .form-submit {
            width: 100%;
            margin-top: 10px;
        }

        .form-note {
            text-align: center;
            margin-top: 20px;
            font-size: 0.9rem;
            color: #777;
        }

        /* Footer */
        footer {
            background-color: var(--color-dark);
            color: white;
            padding: 60px 0 30px;
        }

        .footer-container {
            display: grid;
            grid-template-columns: repeat(auto-fit, minmax(250px, 1fr));
            gap: 40px;
            margin-bottom: 40px;
        }

        .footer-logo {
            max-width: 180px;
            margin-bottom: 20px;
            filter: brightness(0) invert(1);
        }

        .footer-info p {
            margin-bottom: 10px;
        }

        .footer-info i {
            margin-right: 10px;
            color: var(--color-yellow);
        }

        .social-links {
            display: flex;
            gap: 15px;
            margin-top: 20px;
        }

        .social-link {
            display: flex;
            align-items: center;
            justify-content: center;
            width: 40px;
            height: 40px;
            background-color: rgba(255, 255, 255, 0.1);
            border-radius: 50%;
            color: white;
            font-size: 1.2rem;
            transition: var(--transition);
        }

        .social-link:hover {
            background-color: var(--color-primary);
            transform: translateY(-3px);
        }

        .footer-bottom {
            text-align: center;
            padding-top: 30px;
            border-top: 1px solid rgba(255, 255, 255, 0.1);
            font-size: 0.9rem;
            color: rgba(255, 255, 255, 0.7);
        }

        /* Rainbow Divider */
        .rainbow-divider {
            height: 4px;
            width: 100%;
            background: linear-gradient(to right, var(--color-red), var(--color-orange), var(--color-yellow), var(--color-green), var(--color-blue), var(--color-purple));
            margin: 40px 0;
        }

        /* Animations */
        @keyframes fadeIn {
            from { opacity: 0; transform: translateY(20px); }
            to { opacity: 1; transform: translateY(0); }
        }

        .animate {
            animation: fadeIn 0.8s ease forwards;
        }

        .delay-1 { animation-delay: 0.2s; }
        .delay-2 { animation-delay: 0.4s; }
        .delay-3 { animation-delay: 0.6s; }

        /* Responsive */
        @media (max-width: 768px) {
            .header-phone span {
                display: none;
            }

            .header-cta .btn {
                padding: 10px 15px;
                font-size: 0.9rem;
            }

            .hero {
                padding: 60px 0;
            }

            .services-grid, .attendance-options {
                grid-template-columns: 1fr;
            }

            .form-container {
                padding: 30px 20px;
            }
        }

        /* Success Message */
        .success-message {
            display: none;
            background-color: var(--color-green);
            color: white;
            padding: 20px;
            border-radius: var(--radius);
            text-align: center;
            margin-top: 20px;
        }

        .success-message.show {
            display: block;
            animation: fadeIn 0.5s ease forwards;
        }

        /* Floating WhatsApp Button */
        .whatsapp-float {
            position: fixed;
            bottom: 30px;
            right: 30px;
            background-color: #25D366;
            color: white;
            width: 60px;
            height: 60px;
            border-radius: 50%;
            display: flex;
            align-items: center;
            justify-content: center;
            font-size: 1.8rem;
            box-shadow: 0 4px 12px rgba(37, 211, 102, 0.4);
            z-index: 99;
            transition: var(--transition);
        }

        .whatsapp-float:hover {
            transform: scale(1.1);
            box-shadow: 0 6px 16px rgba(37, 211, 102, 0.5);
        }
    </style>
</head>
<body>
    <!-- Header -->
    <header>
        <div class="container header-container">
            <a href="#" class="logo-link">
                <img src="https://hebbkx1anhila5yf.public.blob.vercel-storage.com/image-removebg-preview-FhjmtUAXUsxwE7iBE6JIx7w7JLtebj.png" alt="Clínica Espaço Arco-Íris" class="logo">
            </a>
            <div class="header-cta">
                <a href="tel:+551933673590" class="header-phone">
                    <i class="fas fa-phone-alt"></i>
                    <span>(19) 3367-3590 / (19) 99311-8859</span>
                </a>
                <a href="#form" class="btn">Agende uma Avaliação</a>
            </div>
        </div>
    </header>

    <!-- Hero Section -->
    <section class="hero">
        <div class="container">
            <div class="hero-content animate">
                <h1>Desenvolvimento completo para seu filho, com carinho e profissionais de confiança</h1>
                <p class="hero-subtitle animate delay-1">Apoio especializado nas áreas de Psicologia, Fonoaudiologia, Psicopedagogia, Psicomotricidade, Terapia Ocupacional, Musicoterapia e Fisioterapia — tudo em um só lugar.</p>
                <div class="hero-cta animate delay-2">
                    <a href="#form" class="btn btn-large">Agende uma Avaliação Gratuita</a>
                </div>
            </div>
        </div>
    </section>

    <!-- Why Choose Us Section -->
    <section class="why-choose">
        <div class="container">
            <div class="section-title animate">
                <h2>Por que escolher a Clínica Espaço Arco-Íris?</h2>
            </div>
            <p class="animate delay-1">Porque seu filho merece mais que um tratamento — ele merece acolhimento, escuta e desenvolvimento completo.</p>

            <div class="benefits-list animate delay-2">
                <div class="benefit-item">
                    <div class="benefit-icon">
                        <i class="fas fa-check"></i>
                    </div>
                    <div class="benefit-text">
                        <strong>Profissionais com mais de 20 anos de experiência</strong>
                    </div>
                </div>
                <div class="benefit-item">
                    <div class="benefit-icon">
                        <i class="fas fa-check"></i>
                    </div>
                    <div class="benefit-text">
                        <strong>Atendimentos humanizados e personalizados</strong>, com foco no bem-estar da criança e da família
                    </div>
                </div>
                <div class="benefit-item">
                    <div class="benefit-icon">
                        <i class="fas fa-check"></i>
                    </div>
                    <div class="benefit-text">
                        <strong>Estrutura acolhedora e pensada para crianças e adolescentes</strong>
                    </div>
                </div>
            </div>

            <div class="connection-text animate delay-3">
                <h3>Cada Criança é Única — E o Cuidado Também Deve Ser</h3>
                <p>Na Clínica Espaço Arco-Íris, entendemos que por trás de cada diagnóstico existe uma criança cheia de potencial, emoções e histórias. Se seu filho tem Síndrome de Down, TEA, Deficiência Intelectual, TDAH, TOD ou dificuldades de aprendizagem, aqui ele encontra um espaço seguro, afetuoso e preparado para acompanhá-lo em cada etapa do desenvolvimento.</p>
                <div class="quote">
                    "Não buscamos apenas tratar. Buscamos acolher, entender e transformar cada progresso em conquista."
                </div>
            </div>
        </div>
    </section>

    <!-- Services Section -->
    <section class="services">
        <div class="container">
            <div class="section-title animate">
                <h2>Serviços Especializados</h2>
            </div>
            <p class="text-center animate delay-1">Tudo o que seu filho precisa — com carinho, técnica e propósito.</p>

            <div class="services-grid">
                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-book-open"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Psicopedagogia</h3>
                        <p class="service-description">Avaliação e intervenção para superar dificuldades de aprendizagem e desenvolver habilidades cognitivas e escolares.</p>
                    </div>
                </div>

                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-brain"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Psicologia Infantil</h3>
                        <p class="service-description">Acompanhamento emocional e comportamental personalizado, promovendo bem-estar e autoconfiança.</p>
                    </div>
                </div>

                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-running"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Psicomotricidade</h3>
                        <p class="service-description">Trabalho com coordenação motora, percepção espacial e integração sensorial — essencial para a autonomia.</p>
                    </div>
                </div>

                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-hands-helping"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Terapia Ocupacional</h3>
                        <p class="service-description">Desenvolvimento de habilidades para o dia a dia, promovendo independência e qualidade de vida.</p>
                    </div>
                </div>

                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-comment-dots"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Fonoaudiologia</h3>
                        <p class="service-description">Tratamento de distúrbios da linguagem, fala e comunicação para uma expressão mais fluida e eficaz.</p>
                    </div>
                </div>

                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-music"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Musicoterapia</h3>
                        <p class="service-description">Estimulação cognitiva, emocional e social por meio da música — uma forma lúdica e poderosa de desenvolvimento.</p>
                    </div>
                </div>

                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-heartbeat"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Fisioterapia</h3>
                        <p class="service-description">Atuação em reabilitação e desenvolvimento motor para ganho de mobilidade, postura e controle dos movimentos.</p>
                    </div>
                </div>

                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-microscope"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Avaliação Neuropsicológica</h3>
                        <p class="service-description">Investigação profunda de funções cognitivas e emocionais para diagnósticos precisos e intervenções eficazes.</p>
                    </div>
                </div>

                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-puzzle-piece"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Atendimento ABA e Convencional</h3>
                        <p class="service-description">Acompanhamentos personalizados, com metodologia aplicada para crianças com TEA e outras necessidades.</p>
                    </div>
                </div>

                <div class="service-card animate">
                    <div class="service-icon">
                        <i class="fas fa-home"></i>
                    </div>
                    <div class="service-content">
                        <h3 class="service-title">Visitas Escolares e Domiciliares</h3>
                        <p class="service-description">Quando necessário, acompanhamos seu filho em ambientes externos para ampliar a efetividade do tratamento.</p>
                    </div>
                </div>
            </div>
        </div>
    </section>

    <!-- Attendance Section -->
    <section class="attendance">
        <div class="container">
            <div class="section-title animate">
                <h2>Formas de Atendimento</h2>
            </div>
            <p class="text-center animate delay-1">Na Clínica Espaço Arco-Íris, acreditamos que toda criança merece acesso ao melhor cuidado possível. Por isso, oferecemos diferentes formas de atendimento para se adequar à sua realidade:</p>

            <div class="attendance-options">
                <div class="attendance-card animate">
                    <h3 class="attendance-title">Convênios Médicos</h3>
                    <p>Atendemos pelos principais convênios para facilitar o acesso ao tratamento ideal:</p>
                    <ul class="attendance-list">
                        <li><i class="fas fa-check-circle"></i> Unimed Campinas (por liminar judicial)</li>
                        <li><i class="fas fa-check-circle"></i> Unimed Piracicaba (por liminar judicial)</li>
                        <li><i class="fas fa-check-circle"></i> Unimed FESP (por liminar judicial)</li>
                        <li><i class="fas fa-check-circle"></i> Beneficência Portuguesa</li>
                        <li><i class="fas fa-check-circle"></i> Saúde Petrobras</li>
                    </ul>
                    <a href="tel:+551933673590" class="attendance-cta">
                        <i class="fas fa-phone-alt"></i> Entre em contato para verificar se atendemos o seu plano de saúde
                    </a>
                </div>

                <div class="attendance-card animate">
                    <h3 class="attendance-title">Atendimento Particular</h3>
                    <p>Planos e pacotes pensados para oferecer acessibilidade, sem abrir mão da qualidade:</p>
                    <ul class="attendance-list">
                        <li><i class="fas fa-check-circle"></i> Avaliação inicial com valores acessíveis</li>
                        <li><i class="fas fa-check-circle"></i> Planos mensais personalizados</li>
                        <li><i class="fas fa-check-circle"></i> Pacotes com desconto</li>
                        <li><i class="fas fa-check-circle"></i> Diversas opções de pagamento</li>
                    </ul>
                    <a href="#form" class="attendance-cta">
                        <i class="fas fa-rainbow"></i> Entre em contato para conhecer nossos valores e condições especiais!
                    </a>
                </div>
            </div>
        </div>
    </section>

    <!-- CTA Section -->
    <section class="cta-section">
        <div class="container">
            <h2 class="animate">Agende uma Avaliação Gratuita</h2>
            <p class="cta-text animate delay-1">Dê o primeiro passo para transformar o desenvolvimento do seu filho. Nossa equipe está pronta para ajudar com acolhimento, profissionalismo e um plano feito sob medida. Avaliação inicial sem compromisso.</p>
            <a href="#form" class="btn btn-large btn-secondary animate delay-2">Quero Agendar Agora</a>
        </div>
    </section>

    <!-- Form Section -->
    <section id="form" class="form-section">
        <div class="container">
            <div class="form-container animate">
                <div class="form-title">
                    <h2>Solicite um Agendamento</h2>
                    <p>Preencha o formulário abaixo e entraremos em contato em breve.</p>
                </div>

                <form id="contact-form">
                    <div class="form-group">
                        <label for="name" class="form-label">Nome Completo (do/a responsável)*</label>
                        <input type="text" id="name" name="name" class="form-control" required>
                    </div>

                    <div class="form-group">
                        <label for="email" class="form-label">E-mail*</label>
                        <input type="email" id="email" name="email" class="form-control" required>
                    </div>

                    <div class="form-group">
                        <label for="phone" class="form-label">Telefone (WhatsApp)*</label>
                        <input type="tel" id="phone" name="phone" class="form-control" required>
                    </div>

                    <div class="form-group">
                        <label for="child-name" class="form-label">Nome da criança ou adolescente*</label>
                        <input type="text" id="child-name" name="child-name" class="form-control" required>
                    </div>

                    <div class="form-group">
                        <label for="age" class="form-label">Idade*</label>
                        <input type="number" id="age" name="age" class="form-control" required min="0" max="18">
                    </div>

                    <div class="form-group">
                        <label for="message" class="form-label">Motivo da Consulta*</label>
                        <textarea id="message" name="message" class="form-control" required placeholder="Descreva brevemente as necessidades da criança ou adolescente"></textarea>
                    </div>

                    <button type="submit" class="btn form-submit">Solicitar Agendamento</button>

                    <div id="success-message" class="success-message">
                        <i class="fas fa-check-circle"></i> Sua solicitação foi enviada com sucesso! Em breve entraremos em contato.
                    </div>
                </form>

                <p class="form-note">* Campos obrigatórios</p>
            </div>
        </div>
    </section>

    <!-- Footer -->
    <footer>
        <div class="container">
            <div class="footer-container">
                <div class="footer-info">
                    <img src="https://hebbkx1anhila5yf.public.blob.vercel-storage.com/image-removebg-preview-FhjmtUAXUsxwE7iBE6JIx7w7JLtebj.png" alt="Clínica Espaço Arco-Íris" class="footer-logo">
                    <p><i class="fas fa-map-marker-alt"></i> Rua Frei Antônio de Pádua, 1050 - Jardim Guanabara, Campinas - SP, 13073-330</p>
                    <p><i class="fas fa-phone-alt"></i> (19) 3367-3590 / (19) 99311-8859</p>
                    <p><i class="fas fa-envelope"></i> secretariaespacoarcoiris@gmail.com</p>

                    <div class="social-links">
                        <a href="https://www.instagram.com/espacoarcoiristerapias/" target="_blank" class="social-link">
                            <i class="fab fa-instagram"></i>
                        </a>
                        <a href="https://wa.me/5519993118859" target="_blank" class="social-link">
                            <i class="fab fa-whatsapp"></i>
                        </a>
                    </div>
                </div>
            </div>

            <div class="footer-bottom">
                <p>&copy; 2025 Clínica Espaço Arco-Íris. Todos os direitos reservados.</p>
            </div>
        </div>
    </footer>

    <!-- Floating WhatsApp Button -->
    <a href="https://wa.me/5519993118859" target="_blank" class="whatsapp-float">
        <i class="fab fa-whatsapp"></i>
    </a>

    <!-- JavaScript -->
    <script>
        // Animate elements when they come into view
        document.addEventListener('DOMContentLoaded', function() {
            const animateElements = document.querySelectorAll('.animate');

            const observer = new IntersectionObserver((entries) => {
                entries.forEach(entry => {
                    if (entry.isIntersecting) {
                        entry.target.style.opacity = 1;
                        entry.target.style.transform = 'translateY(0)';
                    }
                });
            }, { threshold: 0.1 });

            animateElements.forEach(element => {
                element.style.opacity = 0;
                element.style.transform = 'translateY(20px)';
                observer.observe(element);
            });

            // Smooth scroll for anchor links
            document.querySelectorAll('a[href^="#"]').forEach(anchor => {
                anchor.addEventListener('click', function(e) {
                    e.preventDefault();

                    const targetId = this.getAttribute('href');
                    if (targetId === '#') return;

                    const targetElement = document.querySelector(targetId);
                    if (targetElement) {
                        window.scrollTo({
                            top: targetElement.offsetTop - 80,
                            behavior: 'smooth'
                        });
                    }
                });
            });

            // Form submission
            const contactForm = document.getElementById('contact-form');
            const successMessage = document.getElementById('success-message');

            if (contactForm) {
                contactForm.addEventListener('submit', function(e) {
                    e.preventDefault();

                    // In a real implementation, you would send the form data to the server here
                    // For this example, we'll just show the success message

                    // Simulate form submission
                    setTimeout(() => {
                        contactForm.reset();
                        successMessage.classList.add('show');

                        // Hide success message after 5 seconds
                        setTimeout(() => {
                            successMessage.classList.remove('show');
                        }, 5000);
                    }, 1000);

                    // In a real implementation, you would use something like:
                    /*
                    const formData = new FormData(contactForm);

                    fetch('your-endpoint', {
                        method: 'POST',
                        body: formData
                    })
                    .then(response => response.json())
                    .then(data => {
                        contactForm.reset();
                        successMessage.classList.add('show');

                        setTimeout(() => {
                            successMessage.classList.remove('show');
                        }, 5000);
                    })
                    .catch(error => {
                        console.error('Error:', error);
                        // Show error message
                    });
                    */
                });
            }
        });
    </script>
</body>
</html>
